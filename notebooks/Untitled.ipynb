# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data_3.csv")

# %%
data
# Out:
#      Unnamed: 0         dt  openvr_local_velocity_x  openvr_local_velocity_y  \
# 0             0   0.100030                 0.001061                 0.004351
# 1             1   0.200165                -0.003059                -0.001721
# 2             2   0.300205                 0.002291                -0.001777
# 3             3   0.400256                -0.000579                 0.002606
# 4             4   0.500522                 0.000514                -0.003044
# ..          ...        ...                      ...                      ...
# 129         129  13.017958                 0.002074                 0.011070
# 130         130  13.118000                -0.014745                 0.010429
# 131         131  13.218021                -0.023323                 0.024121
# 132         132  13.318085                -0.016730                 0.019494
# 133         133  13.418175                -0.017964                 0.004588
#
#      openvr_local_velocity_z  openvr_local_velocity_degx  \
# 0                  -0.001756                    0.001263
# 1                  -0.000391                   -0.000811
# 2                   0.001523                    0.000248
# 3                  -0.002769                    0.001304
# 4                   0.002683                   -0.000847
# ..                       ...                         ...
# 129                -0.069227                   -0.059541
# 130                -0.089369                   -0.002664
# 131                -0.072948                   -0.005625
# 132                -0.078111                    0.004430
# 133                -0.080185                    0.022960
#
#      openvr_local_velocity_degy  openvr_local_velocity_degz  \
# 0                      0.001870                    0.001167
# 1                     -0.000305                   -0.002042
# 2                      0.000776                   -0.002033
# 3                      0.000787                   -0.000947
# 4                      0.001842                    0.000084
# ..                          ...                         ...
# 129                    0.024910                   -0.009986
# 130                    0.003734                   -0.025711
# 131                   -0.054711                    0.023470
# 132                    0.008055                   -0.008467
# 133                    0.013378                   -0.029380
#
#      imu_local_velocity_x  imu_local_velocity_y  ...  openvr_local_accel_z  \
# 0               -0.060889             -0.051198  ...          3.719870e-06
# 1               -0.122158             -0.103406  ...          3.053038e-07
# 2               -0.183096             -0.155808  ...         -1.927965e-06
# 3               -0.242640             -0.208748  ...          3.945716e-06
# 4               -0.302310             -0.260588  ...          1.714160e-06
# ..                    ...                   ...  ...                   ...
# 129             -2.074348             -1.785540  ...         -7.630309e-04
# 130             -2.085966             -1.784724  ...          3.557606e-05
# 131             -2.096659             -1.784014  ...         -1.495842e-03
# 132             -2.087587             -1.779395  ...          2.114130e-04
# 133             -2.087759             -1.777435  ...          3.402042e-04
#
#      openvr_local_accel_degx  openvr_local_accel_degy  \
# 0               5.557181e-08            -3.735579e-07
# 1              -1.168592e-07             3.455068e-07
# 2              -1.917201e-07             6.236843e-08
# 3               3.699045e-07             3.823614e-07
# 4              -1.193059e-07             4.465000e-07
# ..                       ...                      ...
# 129            -1.538255e-05            -3.797434e-06
# 130             2.223077e-07             4.551046e-07
# 131            -1.099044e-05            -3.110046e-06
# 132            -2.486396e-06             7.953631e-07
# 133             7.358948e-06            -3.803689e-06
#
#      openvr_local_accel_degz  imu_local_accel_x  imu_local_accel_y  \
# 0               2.163201e-07          -0.553661          -0.615880
# 1              -1.054742e-07          -0.549415          -0.495166
# 2              -6.789696e-08          -0.535846          -0.510720
# 3              -4.302952e-08          -0.594481          -0.461765
# 4              -3.982412e-08          -0.525634          -0.556272
# ..                       ...                ...                ...
# 129             3.607489e-06          -0.186487           0.110362
# 130             2.359279e-06          -0.047378           0.121803
# 131             1.449488e-06          -0.342767          -0.019335
# 132             4.606006e-07           0.082092           0.067876
# 133            -2.367877e-06           0.118804           0.074460
#
#      imu_local_accel_z  imu_local_accel_degx  imu_local_accel_degy  \
# 0             0.079031              0.000000              0.000000
# 1             0.230823              0.000000              0.000000
# 2            -0.040605              0.000000              0.000000
# 3             0.107980              0.000000              0.000000
# 4             0.036020              0.000000              0.000000
# ..                 ...                   ...                   ...
# 129          -0.172259            626.886366          -1021.815905
# 130          -0.050146             88.821389            115.875255
# 131           0.501470            220.063219            460.365772
# 132          -0.071385           -125.695690            261.763509
# 133          -0.167992              0.000000              0.000000
#
#      imu_local_accel_degz
# 0                0.000000
# 1                0.000000
# 2                0.000000
# 3                0.000000
# 4                0.000000
# ..                    ...
# 129           -269.859584
# 130           -119.758135
# 131           -745.956275
# 132            305.179617
# 133              0.000000
#
# [134 rows x 26 columns]

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_local_velocity_x'],label="openvr_x")
plt.plot(data['dt'],data['imu_local_velocity_x'],label="imu_x")
plt.legend()
plt.show()

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_local_velocity_y'],label="openvr_y")
plt.plot(data['dt'],data['imu_local_velocity_y'],label="imu_y")
plt.legend()
plt.show()

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_local_velocity_z'],label="openvr_z")
plt.plot(data['dt'],data['imu_local_velocity_z'],label="imu_z")
plt.legend()
plt.show()
