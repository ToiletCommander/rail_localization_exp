# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/training_data/data_1663919721.csv")

# %%
data
# Out:
#      Unnamed: 0          dt  kalman_vx  kalman_vy  kalman_vz    imu_vx  \
# 0             0    2.668649  -0.017643   0.029154   0.133618 -0.004355
# 1             1    3.168738   0.001094  -0.004422   0.019639 -0.003221
# 2             2    3.669604  -0.009146  -0.007157  -0.013233 -0.003916
# 3             3    4.170549   0.006026  -0.005676   0.009736 -0.001920
# 4             4    4.671276   0.001413   0.005686   0.010742  0.003726
# ..          ...         ...        ...        ...        ...       ...
# 570         570  367.869835  -0.013597   0.011999  -0.010611 -0.068250
# 571         571  368.369998   0.005400  -0.002106  -0.004599 -0.074166
# 572         572  368.870714  -0.000791   0.024418  -0.010106 -0.078983
# 573         573  369.370936  -0.000556   0.002031  -0.006884 -0.093745
# 574         574  371.572153   0.006781  -0.052732  -0.078356  1.741796
#
#        imu_vy    imu_vz   foot_vx   foot_vy   foot_vz  openvr_vx  openvr_vy  \
# ...

# %%
# plot x velocity
plt.plot(data['dt'],data['kalman_vx'],label="kalman_vx")
#plt.plot(data['dt'],data['imu_vx'],label="imu_vx")
plt.plot(data['dt'],data['foot_vx'],label="foot_vx")
plt.plot(data['dt'],data['openvr_vx'],label="openvr_vx")
plt.legend()
plt.show()

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_vy'],label="openvr_vy")
#plt.plot(data['dt'],data['imu_vy'],label="imu_vy")
plt.plot(data['dt'],data['foot_vy'],label="foot_vy")
plt.plot(data['dt'],data['kalman_vy'],label='kalman_vy')
plt.legend()
plt.show()

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_vz'],label="openvr_vz")
#plt.plot(data['dt'],data['imu_vz'],label="imu_vz")
plt.plot(data['dt'],data['foot_vz'],label="foot_vz")
plt.plot(data['dt'],data['kalman_vz'],label='kalman_vz')
plt.legend()
plt.show()
