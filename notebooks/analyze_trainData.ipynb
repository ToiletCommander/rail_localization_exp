# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/training_data/data.csv")

# %%
data
# Out:
#        Unnamed: 0         dt  kalman_vx  kalman_vy  kalman_vz     imu_vx  \
# 0               0   2.594000  -0.000018  -0.004444   0.010477  -0.183415
# 1               1   2.660833   0.000667  -0.013207   0.008952  -0.304102
# 2               2   2.662396   0.026601  -0.011522   0.042238  -0.298750
# 3               3   2.663485   0.033989  -0.005724   0.061351  -0.281849
# 4               4   2.664672   0.031951  -0.004977   0.047868  -0.294010
# ...           ...        ...        ...        ...        ...        ...
# 45921       45921  86.519598   0.005684  -0.054867  -0.030486  58.628341
# 45922       45922  86.520624   0.007214  -0.057834  -0.027752  58.675109
# 45923       45923  86.521607   0.037247  -0.048572  -0.010574  58.701610
# 45924       45924  86.522664   0.035357  -0.046720   0.002600  58.727770
# 45925       45925  86.523704   0.002118  -0.051539  -0.030874  58.753875
#
#           imu_vy    imu_vz  openvr_vx  openvr_vy  openvr_vz
# 0       0.446436  4.399001   0.004347   0.003690  -0.004105
# 1       0.637527  6.139501  -0.034023  -0.264780   0.050158
# 2       0.618383  5.934857  -0.034031  -0.264795   0.050073
# 3       0.570680  5.445104  -0.034038  -0.264808   0.050000
# 4       0.603111  5.750414  -0.034044  -0.264820   0.049932
# ...          ...       ...        ...        ...        ...
# 45921 -48.409876  1.283929  -0.232798   0.023419   0.029138
# 45922 -48.361158  1.401507  -0.232804   0.023502   0.029019
# 45923 -48.339383  1.388700  -0.236542   0.024963   0.033300
# 45924 -48.317826  1.409166  -0.238149   0.026884   0.037319
# 45925 -48.296128  1.420350  -0.238157   0.026978   0.037204
#
# [45926 rows x 11 columns]

# %%
# plot x velocity
plt.plot(data['dt'],data['kalman_vx'],label="kalman_vx")
#plt.plot(data['dt'],data['imu_vx'],label="imu_xx")
plt.plot(data['dt'],data['openvr_vx'],label="openvr_vx")
plt.legend()
plt.show()

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_vy'],label="openvr_vy")
#plt.plot(data['dt'],data['imu_vy'],label="imu_vy")
plt.plot(data['dt'],data['kalman_vy'],label='kalman_vy')
plt.legend()
plt.show()

# %%
# plot x velocity
plt.plot(data['dt'],data['openvr_vz'],label="openvr_vz")
plt.plot(data['dt'],data['kalman_vz'],label='kalman_vz')
plt.legend()
plt.show()
